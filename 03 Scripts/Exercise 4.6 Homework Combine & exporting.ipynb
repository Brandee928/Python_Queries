# %%
#libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/brandeefairnot/Library/CloudStorage/OneDrive-Personal/Documents/Instacart Basket Analysis/'

# %%
#3 In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.
df_merged_large = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_merged_large
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434484   2977660   206209    prior            13          1
# 32434485   2977660   206209    prior            13          1
# 32434486   2977660   206209    prior            13          1
# 32434487   2977660   206209    prior            13          1
# 32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
#4 Check the shape of the imported dataframe 
df_merged_large.shape
# Out:
# (32434489, 11)

# %% [markdown]
# the shape is the same as the exported data.

# %%
#5 Determine a suitable way to combine the orders_products_combined dataframe with your products data set.

# %%
# cleaned up products doc from 4.5 exercise

df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]
df_dups = df_prods_clean[df_prods_clean.duplicated()]
df_prods_clean.drop_duplicates()
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products_checked.csv'))

# %%
df_prods_clean_no_dups
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
#combining both dataframes
df_prods_combined = df_merged_large.merge(df_prods_clean_no_dups, on = ['product_id'])

# %%
df_prods_combined
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32404854   1320836   202557    prior            17          2
# 32404855     31526   202557    prior            18          5
# 32404856    758936   203436    prior             1          2
# 32404857   2745165   203436    prior             2          3
# 32404858   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
#6 Confirm the results of the merge using the merge flag.
df_prods_combined['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#checking the merged info with outer
df_prods_combined_ = df_merged_large.merge(df_prods_clean_no_dups, on = ['product_id'], how='outer')

# %%
df_prods_combined_['_merge'].value_counts()
# Out:
# both          32435059
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# The outer merged DF has more lines than my inner merged DF. But both lists are match on the both lines.

# %%
#7 Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size).
df_prods_combined.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
